# %%
import pandas as pd
import numpy as np
import json
import glob
import os

def to_serializable(obj):
    if isinstance(obj, np.ndarray):
        return obj.tolist()
    elif isinstance(obj, dict):
        return {k: to_serializable(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [to_serializable(i) for i in obj]
    else:
        return obj
    
def remove_none_keys(value):
    if isinstance(value, dict):
        return {k: v for k, v in value.items() if v is not None}
    return value  # Leave as-is (e.g., if list or str)

# Pattern for your parquet files
file_pattern = "dataset/articles_entertainment_step_*.parquet"

# Output folder (optional)
output_folder = "cleaned_parquet"
os.makedirs(output_folder, exist_ok=True)

# Process each matching file
for filepath in glob.glob(file_pattern):
    print(f"Processing: {filepath}")
    
    # Load the parquet file
    df = pd.read_parquet(filepath)

    # Remove None values
    df["coref_clusters"] = df["coref_clusters"].apply(remove_none_keys)
    df["person_descriptions"] = df["person_descriptions"].apply(remove_none_keys)

    # Convert specific columns
    for col in ["coref_clusters", "person_descriptions"]:
        if col in df.columns:
            df[col] = df[col].apply(lambda x: json.dumps(to_serializable(x), ensure_ascii=False))

    # Save the updated DataFrame to a new Parquet file
    output_path = os.path.join(output_folder, os.path.basename(filepath))
    df.to_parquet(output_path, index=False)
    print(f"Saved cleaned file to: {output_path}")
# Out:
# Processing: dataset/articles_entertainment_step_1.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_1.parquet
# Processing: dataset/articles_entertainment_step_2.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_2.parquet
# Processing: dataset/articles_entertainment_step_3.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_3.parquet
# Processing: dataset/articles_entertainment_step_4.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_4.parquet
# Processing: dataset/articles_entertainment_step_5.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_5.parquet
# Processing: dataset/articles_entertainment_step_6.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_6.parquet
# Processing: dataset/articles_entertainment_step_7.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_7.parquet
# Processing: dataset/articles_entertainment_step_8.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_8.parquet
# Processing: dataset/articles_entertainment_step_9.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_9.parquet
# Processing: dataset/articles_entertainment_step_10.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_10.parquet
# Processing: dataset/articles_entertainment_step_11.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_11.parquet
# Processing: dataset/articles_entertainment_step_12.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_12.parquet
# Processing: dataset/articles_entertainment_step_13.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_13.parquet
# Processing: dataset/articles_entertainment_step_14.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_14.parquet
# Processing: dataset/articles_entertainment_step_15.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_15.parquet
# Processing: dataset/articles_entertainment_step_16.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_16.parquet
# Processing: dataset/articles_entertainment_step_17.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_17.parquet
# Processing: dataset/articles_entertainment_step_18.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_18.parquet
# Processing: dataset/articles_entertainment_step_19.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_19.parquet
# Processing: dataset/articles_entertainment_step_20.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_20.parquet
# Processing: dataset/articles_entertainment_step_21.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_21.parquet
# Processing: dataset/articles_entertainment_step_22.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_22.parquet
# Processing: dataset/articles_entertainment_step_23.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_23.parquet
# Processing: dataset/articles_entertainment_step_24.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_24.parquet
# Processing: dataset/articles_entertainment_step_25.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_25.parquet
# Processing: dataset/articles_entertainment_step_26.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_26.parquet
# Processing: dataset/articles_entertainment_step_27.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_27.parquet
# Processing: dataset/articles_entertainment_step_28.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_28.parquet
# Processing: dataset/articles_entertainment_step_29.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_29.parquet
# Processing: dataset/articles_entertainment_step_30.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_30.parquet
# Processing: dataset/articles_entertainment_step_31.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_31.parquet
# Processing: dataset/articles_entertainment_step_32.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_32.parquet
# Processing: dataset/articles_entertainment_step_33.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_33.parquet
# Processing: dataset/articles_entertainment_step_34.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_34.parquet
# Processing: dataset/articles_entertainment_step_35.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_35.parquet
# Processing: dataset/articles_entertainment_step_36.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_36.parquet
# Processing: dataset/articles_entertainment_step_37.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_37.parquet
# Processing: dataset/articles_entertainment_step_38.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_38.parquet
# Processing: dataset/articles_entertainment_step_39.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_39.parquet
# Processing: dataset/articles_entertainment_step_40.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_40.parquet
# Processing: dataset/articles_entertainment_step_41.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_41.parquet
# Processing: dataset/articles_entertainment_step_42.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_42.parquet
# Processing: dataset/articles_entertainment_step_43.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_43.parquet
# Processing: dataset/articles_entertainment_step_44.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_44.parquet
# Processing: dataset/articles_entertainment_step_45.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_45.parquet
# Processing: dataset/articles_entertainment_step_46.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_46.parquet
# Processing: dataset/articles_entertainment_step_47.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_47.parquet
# Processing: dataset/articles_entertainment_step_48.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_48.parquet
# Processing: dataset/articles_entertainment_step_49.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_49.parquet
# Processing: dataset/articles_entertainment_step_50.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_50.parquet
# Processing: dataset/articles_entertainment_step_51.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_51.parquet
# Processing: dataset/articles_entertainment_step_52.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_52.parquet
# Processing: dataset/articles_entertainment_step_53.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_53.parquet
# Processing: dataset/articles_entertainment_step_54.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_54.parquet
# Processing: dataset/articles_entertainment_step_55.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_55.parquet
# Processing: dataset/articles_entertainment_step_56.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_56.parquet
# Processing: dataset/articles_entertainment_step_57.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_57.parquet
# Processing: dataset/articles_entertainment_step_58.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_58.parquet
# Processing: dataset/articles_entertainment_step_59.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_59.parquet
# Processing: dataset/articles_entertainment_step_60.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_60.parquet
# Processing: dataset/articles_entertainment_step_61.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_61.parquet
# Processing: dataset/articles_entertainment_step_62.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_62.parquet
# Processing: dataset/articles_entertainment_step_63.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_63.parquet
# Processing: dataset/articles_entertainment_step_64.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_64.parquet
# Processing: dataset/articles_entertainment_step_65.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_65.parquet
# Processing: dataset/articles_entertainment_step_66.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_66.parquet
# Processing: dataset/articles_entertainment_step_67.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_67.parquet
# Processing: dataset/articles_entertainment_step_68.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_68.parquet
# Processing: dataset/articles_entertainment_step_69.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_69.parquet
# Processing: dataset/articles_entertainment_step_70.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_70.parquet
# Processing: dataset/articles_entertainment_step_71.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_71.parquet
# Processing: dataset/articles_entertainment_step_72.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_72.parquet
# Processing: dataset/articles_entertainment_step_73.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_73.parquet
# Processing: dataset/articles_entertainment_step_74.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_74.parquet
# Processing: dataset/articles_entertainment_step_75.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_75.parquet
# Processing: dataset/articles_entertainment_step_76.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_76.parquet
# Processing: dataset/articles_entertainment_step_77.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_77.parquet
# Processing: dataset/articles_entertainment_step_78.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_78.parquet
# Processing: dataset/articles_entertainment_step_79.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_79.parquet
# Processing: dataset/articles_entertainment_step_80.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_80.parquet
# Processing: dataset/articles_entertainment_step_81.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_81.parquet
# Processing: dataset/articles_entertainment_step_82.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_82.parquet
# Processing: dataset/articles_entertainment_step_83.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_83.parquet
# Processing: dataset/articles_entertainment_step_84.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_84.parquet
# Processing: dataset/articles_entertainment_step_85.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_85.parquet
# Processing: dataset/articles_entertainment_step_86.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_86.parquet
# Processing: dataset/articles_entertainment_step_87.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_87.parquet
# Processing: dataset/articles_entertainment_step_88.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_88.parquet
# Processing: dataset/articles_entertainment_step_89.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_89.parquet
# Processing: dataset/articles_entertainment_step_90.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_90.parquet
# Processing: dataset/articles_entertainment_step_91.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_91.parquet
# Processing: dataset/articles_entertainment_step_92.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_92.parquet
# Processing: dataset/articles_entertainment_step_93.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_93.parquet
# Processing: dataset/articles_entertainment_step_94.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_94.parquet
# Processing: dataset/articles_entertainment_step_95.parquet
# Saved cleaned file to: cleaned_parquet/articles_entertainment_step_95.parquet

# %%
import pandas as pd
import glob
import os

# Directory containing the cleaned parquet files
cleaned_dir = "cleaned_parquet"

# Find and sort all cleaned parquet files by chunk number
cleaned_files = sorted(
    glob.glob(os.path.join(cleaned_dir, "articles_entertainment_step_*.parquet")),
    key=lambda x: int(x.split("_step_")[-1].split(".")[0])
)

# Load and concatenate all cleaned chunks
dfs = []
for f in cleaned_files:
    print(f"Loading cleaned file: {f}")
    df_chunk = pd.read_parquet(f)
    dfs.append(df_chunk)

# Combine into a single DataFrame
df_combined = pd.concat(dfs, ignore_index=True)

# Output path for the full combined dataset
combined_path = os.path.join(cleaned_dir, "articles_entertainment_nlp.parquet")
df_combined.to_parquet(combined_path)
print(f"✅ Combined cleaned DataFrame saved to: {combined_path}")
# Out:
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_1.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_2.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_3.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_4.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_5.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_6.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_7.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_8.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_9.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_10.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_11.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_12.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_13.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_14.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_15.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_16.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_17.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_18.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_19.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_20.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_21.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_22.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_23.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_24.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_25.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_26.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_27.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_28.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_29.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_30.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_31.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_32.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_33.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_34.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_35.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_36.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_37.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_38.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_39.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_40.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_41.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_42.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_43.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_44.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_45.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_46.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_47.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_48.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_49.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_50.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_51.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_52.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_53.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_54.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_55.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_56.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_57.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_58.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_59.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_60.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_61.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_62.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_63.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_64.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_65.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_66.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_67.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_68.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_69.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_70.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_71.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_72.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_73.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_74.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_75.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_76.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_77.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_78.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_79.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_80.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_81.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_82.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_83.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_84.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_85.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_86.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_87.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_88.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_89.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_90.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_91.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_92.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_93.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_94.parquet
# Loading cleaned file: cleaned_parquet/articles_entertainment_step_95.parquet
# ✅ Combined cleaned DataFrame saved to: cleaned_parquet/articles_entertainment_nlp.parquet
